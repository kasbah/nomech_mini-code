# %%
import sys, time
sys.path.append("../../tools/python_module")
import nomech

# %%
data_untouched_1 = nomech.read(samples=1000, electrodes=1)[0]
data_untouched_2 = nomech.read(samples=100000, electrodes=1)[0]

# %%
plot(data_untouched_1)

# %%
plot(data_untouched_2)

# %%
data_untouched_1 = nomech.read(samples=1000, electrodes=1)[0]
data_untouched_2 = nomech.read(samples=100000, electrodes=1)[0]

# %%
plot(data_untouched_1)

# %%
plot(data_untouched_2)

# %%
data_untouched_1 = nomech.read(samples=1000, electrodes=1)[0]
data_untouched_2 = nomech.read(samples=1000000, electrodes=1)[0]

# %%
plot(data_untouched_1)

# %%
plot(data_untouched_2)

# %%
data_untouched_1 = nomech.read(samples=1000, electrodes=1)[0]
data_untouched_2 = nomech.read(samples=1000000, electrodes=1)[0]

# %%
plot(data_untouched_1)

# %%
plot(data_untouched_2)

# %%
data_untouched_1 = nomech.read(samples=1000, electrodes=1)[0]
data_untouched_2 = nomech.read(samples=1000000, electrodes=1)[0]

# %%
plot(data_untouched_1)

# %%
plot(data_untouched_2)

# %%
data_untouched_1 = nomech.read(samples=1000, electrodes=1)[0]
data_untouched_2 = nomech.read(samples=10000000, electrodes=1)[0]

# %%
plot(data_untouched_1)

# %%
plot(data_untouched_2)

# %%
data_untouched_1 = nomech.read(samples=1000, electrodes=1)[0]
data_untouched_2 = nomech.read(samples=10000000, electrodes=1)[0]

# %%
plot(data_untouched_1)

# %%
plot(data_untouched_2)

# %%
plot(nomech.read(samples=1000, electrodes=1)[0])

# %%
plot(nomech.read(samples=1000, electrodes=1)[0]) #touched

# %%
plot(nomech.read(samples=1000, electrodes=1)[0])

# %%
plot(nomech.read(samples=1000, electrodes=1)[0]) #re-plugged

# %%
plot(nomech.read(samples=1000, electrodes=1)[0]) #after being left for the night

# %%
plot(nomech.read(samples=100000, electrodes=1)[0])
