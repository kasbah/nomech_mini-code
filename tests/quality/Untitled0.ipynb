# %%
import sys
sys.path.append("../../tools/python_module")
import nomech
import time

# %%
data_untouched_1 = nomech.read(samples=10000, electrodes=1)[0]
plot(data_untouched_1)
data_untouched_2 = nomech.read(samples=10000, electrodes=1)[0]
plot(data_untouched_2)

# %%
data_touched_1 = nomech.read(samples=10000, electrodes=1)[0]
plot(data_touched_1)
data_touched_2 = nomech.read(samples=10000, electrodes=1)[0]
plot(data_touched_2)

# %%
max(data_touched_2)
# Out:
# 4563
