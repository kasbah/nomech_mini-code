# %%
import sys, time
sys.path.append("../../tools/python_module")
import nomech

# %%
data_untouched_1 = nomech.read(samples=200, electrodes=1)[0]
plot(data_untouched_1)

# %%
data_untouched_1 = nomech.read(samples=200, electrodes=1)[0]
plot(data_untouched_1)

# %%
data_untouched_1 = nomech.read(samples=200, electrodes=1)[0]
plot(data_untouched_1)

# %%
data_untouched_1 = nomech.read(samples=200, electrodes=1)[0]
plot(data_untouched_1)

# %% [markdown]
# Now we now we program with: 1d5649ae641

# %%
data_untouched_1 = nomech.read(samples=200, electrodes=1)[0]
plot(data_untouched_1)

# %%
data_untouched_1 = nomech.read(samples=200, electrodes=1)[0]
plot(data_untouched_1)

# %%
data_untouched_1 = nomech.read(samples=200, electrodes=1)[0]
plot(data_untouched_1)

# %% [markdown]
# No change.
