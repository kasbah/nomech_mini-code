# %%
import sys, time, threading
sys.path.append("../../tools/python_module")
import nomech
# %load_ext autoreload
# %autoreload 2

# %%
data_untouched = nomech.read(samples=10000, electrodes=1)[0]
plot(data_untouched)

# %%
data_touched = nomech.read(samples=10000, electrodes=1)[0]
plot(data_touched)

# %%
data_touched = nomech.read(samples=10000, electrodes=1)[0]
plot(data_touched)

# %%
data_untouched = nomech.read(samples=10000, electrodes=1)[0]
plot(data_untouched)

# %%
data_touched = nomech.read(samples=10000, electrodes=1)[0]
plot(data_touched)

# %%
data = data_touched[1400:1600]
plot(data)

# %%
data2 = data[150:200]
plot(data2)

# %%
data3 = data2[20:30]
plot(data3)

# %%
data_touched = nomech.read(samples=10000, electrodes=1)[0]
plot(data_touched)

# %%
plot(data_touched[1400:1600])
